# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn import tree

# %%
data=pd.read_csv("insurance_pre.csv")
data=pd.get_dummies(data,drop_first=True)
data
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=data[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=data[['charges']]

# %%
sc1=StandardScaler()
sc2=StandardScaler()

# %%
x_train=sc1.fit_transform(independent)
y_train=sc2.fit_transform(dependent)

# %%
param_grid={"criterion":['mse','mae','friedman_mse'],"splitter":['best','random'],'max_features':['auto','sqrt','log2']}

# %%
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,n_jobs=-1,verbose=3)
grid.fit(x_train,y_train)
# Out:
# C:\Users\shanm\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Done  42 out of  54 | elapsed:    1.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:    1.4s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
# ...

# %%
grid.best_params_
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
dic=grid.cv_results_
pd.DataFrame(dic)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000      0.000000         0.000000        0.000000
# 1        0.005211      0.007369         0.000000        0.000000
# 2        0.005301      0.007497         0.000000        0.000000
# 3        0.000000      0.000000         0.001836        0.002597
# 4        0.003682      0.004493         0.000338        0.000478
# 5        0.005669      0.007067         0.000000        0.000000
# 6        0.031245      0.000000         0.004007        0.002834
# 7        0.015888      0.004747         0.000000        0.000000
# 8        0.011960      0.002759         0.000000        0.000000
# 9        0.015915      0.000075         0.000000        0.000000
# 10       0.016021      0.000000         0.000000        0.000000
# 11       0.016021      0.000000         0.000000        0.000000
# 12       0.000000      0.000000         0.000000        0.000000
# ...

# %%
y_predict=grid.predict(x_train)

# %%
r2=r2_score(y_train,y_predict)
r2
# Out:
# 0.9986671541430431

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:28
# BMI:33
# Children:3
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
preinput=sc1.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

# %%
fiture_prediction=grid.predict(preinput)

# %%
out=sc2.inverse_transform(fiture_prediction)
out
# Out:
# array([4449.462])
